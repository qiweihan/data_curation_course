# %% [markdown]
# # 2489-1819 Data Curation  T1 Final Exam
#
# The final exam will contain 1 question with subquestions for 70% of the total points (20% for 5 questions in SQL and 50% for Python).
#
# ## Game of Thrones or The Big Bang Theory?
#
# “What movie should I watch this evening?” This perhaps is a question you would ask yourself very often. As for me — yes, and more than once. As such, from Netflix to Hulu, the need to build robust movie recommendation systems is extremely important given the huge demand for personalized content of modern consumers.
#
# We are going to examine a MovieLens dataset which provides non-commercial, personalized movie recommendations.
#
# This dataset describes 5-star rating from MovieLens. It contains ratings and tag applications across movies created by  users. Users were selected at random for inclusion. No demographic information is included. Each user is represented by an id, and no other information is provided.
#
# The data are contained in the files movies.csv, ratings.csv. More details about the contents and use of all these files follows.
#
# **Ratings Data File Structure (ratings_fe.csv)**
# All ratings are contained in the file ratings.csv. Each line of this file after the header row represents one rating of one movie by one user, and has the following format:
# `userId,movieId,rating,timestamp`
#
# The lines within this file are ordered first by userId, then, within user, by movieId.
#
# Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).
#
# **Movies Data File Structure (movies_fe.xlsx)**
# Movie information is contained in the file movies.csv. Each line of this file after the header row represents one movie, and has the following format:
# `movieId,title,year,genres`
#
# The database `movielens_small` contains 4 tables: *ratings, tags, movies and links*. In the multiple choice questions, you need to use these tables to answer those.
#
#
# Answer the following questions using the provided dataset. You can write down intermediate results towards the final answers

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Question 1 (10 points)
#
# However, errors and inconsistencies may exist in these files shown as below:
#
# The ratings in the `rating_fe.csv` should be made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars). So if the ratings that are larger than 5 or smaller than 0.5, you need to round it to the value of 5 and 1. For example, if a movie is rated 8, then it might be wronly rated and you need to change the value to 5. Similarly, if a movie is rated -1, then it should be changed to 1, if any.

# %%
movies = pd.read_excel('movies_fe.xlsx', skiprows=15)

# %%
movies.head()
# Out:
#    movieId                        title    year  \
# 0        1                    Toy Story  1995.0
# 1        2                      Jumanji  1995.0
# 2        3             Grumpier Old Men  1995.0
# 3        4            Waiting to Exhale  1995.0
# 4        5  Father of the Bride Part II  1995.0
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv('ratings_fe.csv', skiprows=10, index_col=0)

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        6     2.0  980730861
# 1       1       22     3.0  980731380
# 2       1       32     2.0  980731926
# 3       1       50     5.0  980732037
# 4       1      110     4.0  980730408

# %%
ratings['rating'].max()
# Out:
# 10.0

# %%
ratings['rating'].min()
# Out:
# -1.0

# %% [markdown]
# Let's correct the wrong values

# %%
ratings.loc[ratings['rating']>5, 'rating'] = 5
ratings.loc[ratings['rating']<0.5, 'rating'] = 1

# %% [markdown]
# ### Question 2 (5 points)
#
# Show the top 5 years with the most number of movies:

# %%
movies['year'].value_counts().head(5)
# Out:
# 2006.0    315
# 2002.0    294
# 1996.0    280
# 1995.0    273
# 1999.0    266
# Name: year, dtype: int64

# %%
movies.groupby('year')[['movieId']].count().reset_index().rename(columns={'movieId':'number_movies'}).sort_values(by='number_movies', ascending=False).head()
# Out:
#       year  number_movies
# 90  2006.0            315
# 86  2002.0            294
# 80  1996.0            280
# 79  1995.0            273
# 83  1999.0            266

# %% [markdown]
# ### Question 3 (5 points)
# Show the average rating of movies with ID 100:

# %%
ratings.loc[ratings['movieId']==100, 'rating'].mean()
# Out:
# 3.328125

# %% [markdown]
# ### Question 4 (5 points)
#
# Show the median ratings given by user with ID 500:

# %%
ratings.loc[ratings['userId']==500, 'rating'].median()
# Out:
# 4.0

# %% [markdown]
# ### Question 5 (10 points)
#
# Among all movies that uer with Id 500 has rated, show the his/her top 10 favorite movies (i.e., the movie he/she rated 5) more recently as three columns: `movieId, title, rating`

# %%
movie_ratings = pd.merge(movies, ratings, on='movieId')

# %%
movie_ratings.loc[movie_ratings['userId']==500].sort_values(['rating', 'timestamp'], ascending=False)[['movieId', 'title', 'rating']].head(10)
# Out:
#        movieId                                              title  rating
# 46923     1924                            Plan 9 from Outer Space     5.0
# 40242     1391                                      Mars Attacks!     5.0
# 51497     2162        NeverEnding Story II: The Next Chapter, The     5.0
# 80453     5502                                              Signs     5.0
# 52040     2232                                               Cube     5.0
# 23276      671            Mystery Science Theater 3000: The Movie     5.0
# 69078     3671                                    Blazing Saddles     5.0
# 52638     2291                                Edward Scissorhands     5.0
# 60174     2788  Monty Python's And Now for Something Completel...     5.0
# 8455       235                                            Ed Wood     5.0

# %% [markdown]
# ### Question 6 (15 points)
#
# Now you need to implement a **recommender system using collaborative filtering method**. This works simply as to recommend movies that "people who like this movie also like these movies". For example, people who like to watch Star Wars are very likely to watch Star Treks.
#
# In order to do so, you need to find out users who like one movie (i.e., post a rating of 5), and count what are the movies these users also like, ranked by the number of likes.
#
# Show the recommended movie list with top 10 movies that users who like the *Titanic* may also like.

# %%
titanic_user = movie_ratings.loc[(movie_ratings['title'] == 'Titanic') & (movie_ratings['rating'] == 5), 'userId']
titanic_user
# Out:
# 44874     46
# 44879     71
# 44894    130
# 44896    145
# 44899    160
# 44921    247
# 44931    289
# 44932    290
# 44934    302
# 44946    352
# 44950    374
# 44956    396
# 44958    413
# 44961    426
# 44964    430
# 44971    463
# 44977    491
# 44983    526
# 44986    550
# 44990    570
# 44992    576
# 44998    599
# 45001    608
# 45006    633
# 45016    683
# 66760    247
# 66765    536
# Name: userId, dtype: int64

# %% [markdown]
# After we extract user list of all users who give the rating of 5 to Titanic, we need to see what other movies these users have given the ratings of 5.

# %%
liked_movies = movie_ratings.loc[(movie_ratings['userId'].isin(titanic_user)) & (movie_ratings['rating'] == 5)
                                & (movie_ratings['title'] != 'Titanic')]
liked_movies
# Out:
#        movieId                                              title    year  \
# 95           1                                          Toy Story  1995.0
# 162          1                                          Toy Story  1995.0
# 179          1                                          Toy Story  1995.0
# 501          5                        Father of the Bride Part II  1995.0
# 762         10                                          GoldenEye  1995.0
# 917         11                            American President, The  1995.0
# 931         11                            American President, The  1995.0
# 935         11                            American President, The  1995.0
# 972         11                            American President, The  1995.0
# 1117        16                                             Casino  1995.0
# 1170        17                              Sense and Sensibility  1995.0
# 1550        21                                         Get Shorty  1995.0
# 1613        22                                            Copycat  1995.0
# 1616        22                                            Copycat  1995.0
# 1707        24                                             Powder  1995.0
# 1812        25                                  Leaving Las Vegas  1995.0
# 2015        32                 Twelve Monkeys (a.k.a. 12 Monkeys)  1995.0
# 2087        32                 Twelve Monkeys (a.k.a. 12 Monkeys)  1995.0
# 2219        34                                               Babe  1995.0
# 2441        36                                   Dead Man Walking  1995.0
# 2507        39                                           Clueless  1995.0
# 2910        47                               Seven (a.k.a. Se7en)  1995.0
# 2926        47                               Seven (a.k.a. Se7en)  1995.0
# 2965        47                               Seven (a.k.a. Se7en)  1995.0
# 2972        47                               Seven (a.k.a. Se7en)  1995.0
# 3217        50                                Usual Suspects, The  1995.0
# 3235        50                                Usual Suspects, The  1995.0
# 3473        60                        Indian in the Cupboard, The  1995.0
# 3580        62                                 Mr. Holland's Opus  1995.0
# 3946        86                                       White Squall  1996.0
# ...        ...                                                ...     ...
# 96728    71745                          Where the Wild Things Are  2009.0
# 96818    72605                                           Brothers  2009.0
# 96880    72998                                             Avatar  2009.0
# 96887    72998                                             Avatar  2009.0
# 96909    73017                                    Sherlock Holmes  2009.0
# 96941    73266                                    Youth in Revolt  2009.0
# 97025    74458                                     Shutter Island  2010.0
# 97028    74458                                     Shutter Island  2010.0
# 97192    76251                                           Kick-Ass  2010.0
# 97269    77846                                       12 Angry Men  1997.0
# 97340    78499                                        Toy Story 3  2010.0
# 97437    79132                                          Inception  2010.0
# 97442    79132                                          Inception  2010.0
# 97536    79702                        Scott Pilgrim vs. the World  2010.0
# 97600    80463                                Social Network, The  2010.0
# 97746    81591                                         Black Swan  2010.0
# 97780    81834       Harry Potter and the Deathly Hallows: Part 1  2010.0
# 97786    81834       Harry Potter and the Deathly Hallows: Part 1  2010.0
# 97788    81834       Harry Potter and the Deathly Hallows: Part 1  2010.0
# 97847    82169  Chronicles of Narnia: The Voyage of the Dawn T...  2010.0
# 98073    85414                                        Source Code  2011.0
# 98316    88125       Harry Potter and the Deathly Hallows: Part 2  2011.0
# 98325    88125       Harry Potter and the Deathly Hallows: Part 2  2011.0
# 98329    88125       Harry Potter and the Deathly Hallows: Part 2  2011.0
# 98495    89745                                      Avengers, The  2012.0
# 98524    89846                    Bobby Fischer Against the World  2011.0
# 98532    89864                                              50/50  2011.0
# 98806    93040                                     Civil War, The  1990.0
# 98853    93821            There's Something Wrong with Aunt Diane  2011.0
# 99720   108583                                 Fawlty Towers (197  1979.0
#
#                                                  genres  userId  rating  \
# 95          Adventure|Animation|Children|Comedy|Fantasy     290     5.0
# 162         Adventure|Animation|Children|Comedy|Fantasy     463     5.0
# 179         Adventure|Animation|Children|Comedy|Fantasy     526     5.0
# 501                                              Comedy     570     5.0
# 762                           Action|Adventure|Thriller     145     5.0
# 917                                Comedy|Drama|Romance     160     5.0
# 931                                Comedy|Drama|Romance     247     5.0
# 935                                Comedy|Drama|Romance     302     5.0
# 972                                Comedy|Drama|Romance     608     5.0
# 1117                                        Crime|Drama     491     5.0
# 1170                                      Drama|Romance     160     5.0
# 1550                              Comedy|Crime|Thriller     570     5.0
# 1613                Crime|Drama|Horror|Mystery|Thriller     396     5.0
# 1616                Crime|Drama|Horror|Mystery|Thriller     426     5.0
# 1707                                       Drama|Sci-Fi     570     5.0
# 1812                                      Drama|Romance     570     5.0
# 2015                            Mystery|Sci-Fi|Thriller     145     5.0
# 2087                            Mystery|Sci-Fi|Thriller     352     5.0
# 2219                                     Children|Drama     145     5.0
# 2441                                        Crime|Drama     570     5.0
# 2507                                     Comedy|Romance     247     5.0
# 2910                                   Mystery|Thriller     374     5.0
# 2926                                   Mystery|Thriller     426     5.0
# 2965                                   Mystery|Thriller     550     5.0
# 2972                                   Mystery|Thriller     570     5.0
# 3217                             Crime|Mystery|Thriller     374     5.0
# 3235                             Crime|Mystery|Thriller     426     5.0
# 3473                         Adventure|Children|Fantasy     302     5.0
# 3580                                              Drama     570     5.0
# 3946                             Action|Adventure|Drama     570     5.0
# ...                                                 ...     ...     ...
# 96728             Adventure|Children|Drama|Fantasy|IMAX     463     5.0
# 96818                                Drama|Thriller|War     463     5.0
# 96880                      Action|Adventure|Sci-Fi|IMAX     463     5.0
# 96887                      Action|Adventure|Sci-Fi|IMAX     550     5.0
# 96909                     Action|Crime|Mystery|Thriller     290     5.0
# 96941                              Comedy|Drama|Romance     290     5.0
# 97025                            Drama|Mystery|Thriller     374     5.0
# 97028                            Drama|Mystery|Thriller     463     5.0
# 97192                                     Action|Comedy     463     5.0
# 97269                                       Crime|Drama     491     5.0
# 97340  Adventure|Animation|Children|Comedy|Fantasy|IMAX     463     5.0
# 97437   Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX     463     5.0
# 97442   Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX     550     5.0
# 97536             Action|Comedy|Fantasy|Musical|Romance     290     5.0
# 97600                                             Drama     550     5.0
# 97746                                    Drama|Thriller     463     5.0
# 97780                     Action|Adventure|Fantasy|IMAX     290     5.0
# 97786                     Action|Adventure|Fantasy|IMAX     463     5.0
# 97788                     Action|Adventure|Fantasy|IMAX     536     5.0
# 97847                        Adventure|Children|Fantasy     290     5.0
# 98073              Action|Drama|Mystery|Sci-Fi|Thriller     463     5.0
# 98316       Action|Adventure|Drama|Fantasy|Mystery|IMAX     290     5.0
# 98325       Action|Adventure|Drama|Fantasy|Mystery|IMAX     463     5.0
# 98329       Action|Adventure|Drama|Fantasy|Mystery|IMAX     536     5.0
# 98495                      Action|Adventure|Sci-Fi|IMAX     463     5.0
# 98524                                       Documentary     491     5.0
# 98532                                      Comedy|Drama     463     5.0
# 98806                                   Documentary|War     491     5.0
# 98853                                       Documentary     491     5.0
# 99720                                            Comedy     491     5.0
#
#         timestamp
# 95     1342626325
# 162    1307067849
# 179     970541258
# 501     905444039
# 762     945467546
# 917     913130528
# 931     994218976
# 935     945111256
# 972     988149788
# 1117   1008829180
# 1170    913130502
# 1550    905442871
# 1613    997711675
# 1616   1005494770
# 1707    905464704
# 1812    905446924
# 2015    959048137
# 2087   1180616771
# 2219    945468713
# 2441    905446486
# 2507    994301174
# 2910   1113779751
# 2926   1005494559
# 2965   1296441553
# 2972    905446829
# 3217   1117403635
# 3235   1005494262
# 3473    971828068
# 3580    905446433
# 3946    905446380
# ...           ...
# 96728  1306909160
# 96818  1306907001
# 96880  1306909239
# 96887  1296443614
# 96909  1324649989
# 96941  1324650223
# 97025  1332945501
# 97028  1306908405
# 97192  1306907161
# 97269  1404790128
# 97340  1310411472
# 97437  1306907225
# 97442  1296441854
# 97536  1324650244
# 97600  1296441904
# 97746  1306906366
# 97780  1324649565
# 97786  1307066782
# 97788  1321318884
# 97847  1324649821
# 98073  1306907267
# 98316  1324649567
# 98325  1349674010
# 98329  1321318887
# 98495  1349674026
# 98524  1365366048
# 98532  1349674022
# 98806  1404789585
# 98853  1365366080
# 99720  1404790436
#
# [1056 rows x 7 columns]

# %% [markdown]
# Now we can count and rank the number of users who like the movie:

# %%
liked_movies = liked_movies.groupby('movieId')[['userId']].count().reset_index().rename(columns={'userId':
                                                                                  'number_users'}).sort_values(by='number_users', 
                                                                                                               ascending=False)

# %%
pd.merge(liked_movies, movies, on='movieId').head(10)
# Out:
#    movieId  number_users                       title    year  \
# 0      593             8   Silence of the Lambs, The  1991.0
# 1     2571             8                 Matrix, The  1999.0
# 2      356             8                Forrest Gump  1994.0
# 3      527             8            Schindler's List  1993.0
# 4      318             8   Shawshank Redemption, The  1994.0
# 5      589             7  Terminator 2: Judgment Day  1991.0
# 6      110             7                  Braveheart  1995.0
# 7     2028             7         Saving Private Ryan  1998.0
# 8     1784             7          As Good as It Gets  1997.0
# 9     2959             6                  Fight Club  1999.0
#
#                         genres
# 0        Crime|Horror|Thriller
# 1       Action|Sci-Fi|Thriller
# 2     Comedy|Drama|Romance|War
# 3                    Drama|War
# 4                  Crime|Drama
# 5                Action|Sci-Fi
# 6             Action|Drama|War
# 7             Action|Drama|War
# 8         Comedy|Drama|Romance
# 9  Action|Crime|Drama|Thriller

# %% [markdown]
# Congratulations! You just build the first recommender system that worth 1 million dollars :D
